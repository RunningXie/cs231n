# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
    np.random.seed(0)#如果使用相同的seed()值，则每次生成的随即数都相同，如果不设置这个值，则系统根据时间来自己选择这个值，此时每次生成的随机数因时间差异而不同。
    return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
    np.random.seed(1)
    X = 10 * np.random.randn(num_inputs, input_size)
    y = np.array([0, 1, 2, 2, 1])
    return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print('Your scores:')
print(scores)
print()
print('correct scores:')
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print(correct_scores)
print()

# The difference should be very small. We get < 1e-7
print('Difference between your scores and correct scores:')
print(np.sum(np.abs(scores - correct_scores)))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.680272093239262e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.05)
correct_loss = 1.30378789133

# should be very small, we get < 1e-12
print('Difference between your loss and correct loss:')
print(np.sum(np.abs(loss - correct_loss)))
# Out:
# Difference between your loss and correct loss:
# 1.7963408538435033e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.05)

# these should all be less than 1e-8 or so
for param_name in grads:
    f = lambda W: net.loss(X, y, reg=0.05)[0]
    param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
    print('%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name])))
# Out:
# W2 max relative error: 3.440708e-09
# b2 max relative error: 2.107308e-10
# W1 max relative error: 3.561318e-09
# b1 max relative error: 1.555470e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
            learning_rate=1e-1, reg=5e-6,
            num_iters=100, verbose=False)

print('Final training loss: ', stats['loss_history'][-1])

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.01714961022246529

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
            num_iters=1000, batch_size=200,
            learning_rate=1e-4, learning_rate_decay=0.95,
            reg=0.25, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print('Validation accuracy: ', val_acc)
# Out:
# iteration 0 / 1000: loss 2.302954
# iteration 100 / 1000: loss 2.302550
# iteration 200 / 1000: loss 2.297648
# iteration 300 / 1000: loss 2.259603
# iteration 400 / 1000: loss 2.204169
# iteration 500 / 1000: loss 2.118563
# iteration 600 / 1000: loss 2.051548
# iteration 700 / 1000: loss 1.988483
# iteration 800 / 1000: loss 2.006583
# iteration 900 / 1000: loss 1.951480
# Validation accuracy:  0.287

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train')
plt.plot(stats['val_acc_history'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net.params['W1']
    W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)#transpose调换了矩阵维度顺序,W1.shape=(50,32,32,3)
    plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
    plt.gca().axis('off')#关闭子图的坐标轴显示
    plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
best_net = None # store the best model into this 

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model in best_net.                                                            #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# Tweaking hyperparameters by hand can be fun, but you might find it useful to  #
# write code to sweep through possible combinations of hyperparameters          #
# automatically like we did on the previous exercises.                          #
#################################################################################
input_size = 32 * 32 * 3
num_classes = 10
best_val=0
for lr in [1e-3, 1e-4, 1e-5]:
    for rs in [0.5,0.25]:
        for bs in [200, 400]:
            for hs in [50, 100, 200]:
                net = TwoLayerNet(input_size, hs, num_classes)
                stats = net.train(X_train, y_train, X_val, y_val,
                            num_iters=2000, batch_size=bs,
                            learning_rate=lr, learning_rate_decay=0.9,
                            reg=rs, verbose=True)
                val_acc = (net.predict(X_val) == y_val).mean()
                print ("batch_size = %d, learning_rate = %f, hidden_size = %f, Valid_accuracy: %f" %(bs, lr, hs,val_acc))
                if val_acc>best_val:
                    best_val=val_acc
                    best_net=net
pass
#################################################################################
#                               END OF YOUR CODE                                #
#################################################################################
# Out:
# iteration 0 / 2000: loss 2.303335
# iteration 100 / 2000: loss 1.976347
# iteration 200 / 2000: loss 1.692467
# iteration 300 / 2000: loss 1.771487
# iteration 400 / 2000: loss 1.600926
# iteration 500 / 2000: loss 1.494159
# iteration 600 / 2000: loss 1.596897
# iteration 700 / 2000: loss 1.538389
# iteration 800 / 2000: loss 1.621566
# iteration 900 / 2000: loss 1.594428
# iteration 1000 / 2000: loss 1.613695
# iteration 1100 / 2000: loss 1.549899
# iteration 1200 / 2000: loss 1.451499
# iteration 1300 / 2000: loss 1.572946
# iteration 1400 / 2000: loss 1.531017
# iteration 1500 / 2000: loss 1.543032
# iteration 1600 / 2000: loss 1.626135
# iteration 1700 / 2000: loss 1.544062
# iteration 1800 / 2000: loss 1.424703
# iteration 1900 / 2000: loss 1.431919
# batch_size = 200, learning_rate = 0.001000, hidden_size = 50.000000, Valid_accuracy: 0.478000
# iteration 0 / 2000: loss 2.304140
# iteration 100 / 2000: loss 1.916274
# iteration 200 / 2000: loss 1.741963
# iteration 300 / 2000: loss 1.730143
# iteration 400 / 2000: loss 1.666190
# iteration 500 / 2000: loss 1.578075
# iteration 600 / 2000: loss 1.521691
# iteration 700 / 2000: loss 1.494132
# iteration 800 / 2000: loss 1.600035
# iteration 900 / 2000: loss 1.564886
# iteration 1000 / 2000: loss 1.590184
# iteration 1100 / 2000: loss 1.685718
# iteration 1200 / 2000: loss 1.587331
# iteration 1300 / 2000: loss 1.554538
# iteration 1400 / 2000: loss 1.491159
# iteration 1500 / 2000: loss 1.625283
# iteration 1600 / 2000: loss 1.550738
# iteration 1700 / 2000: loss 1.455427
# iteration 1800 / 2000: loss 1.513724
# iteration 1900 / 2000: loss 1.393189
# batch_size = 200, learning_rate = 0.001000, hidden_size = 100.000000, Valid_accuracy: 0.489000
# iteration 0 / 2000: loss 2.305670
# iteration 100 / 2000: loss 1.954019
# iteration 200 / 2000: loss 1.794298
# iteration 300 / 2000: loss 1.851434
# iteration 400 / 2000: loss 1.722844
# iteration 500 / 2000: loss 1.656124
# iteration 600 / 2000: loss 1.606810
# iteration 700 / 2000: loss 1.565279
# iteration 800 / 2000: loss 1.654478
# iteration 900 / 2000: loss 1.621037
# iteration 1000 / 2000: loss 1.506021
# iteration 1100 / 2000: loss 1.603710
# iteration 1200 / 2000: loss 1.576849
# iteration 1300 / 2000: loss 1.484856
# iteration 1400 / 2000: loss 1.439134
# iteration 1500 / 2000: loss 1.498683
# iteration 1600 / 2000: loss 1.438591
# iteration 1700 / 2000: loss 1.576126
# iteration 1800 / 2000: loss 1.551843
# iteration 1900 / 2000: loss 1.360223
# batch_size = 200, learning_rate = 0.001000, hidden_size = 200.000000, Valid_accuracy: 0.515000
# iteration 0 / 2000: loss 2.303347
# iteration 100 / 2000: loss 1.955594
# iteration 200 / 2000: loss 1.873468
# iteration 300 / 2000: loss 1.777328
# iteration 400 / 2000: loss 1.652110
# iteration 500 / 2000: loss 1.567756
# iteration 600 / 2000: loss 1.671305
# iteration 700 / 2000: loss 1.683359
# iteration 800 / 2000: loss 1.545676
# iteration 900 / 2000: loss 1.569173
# iteration 1000 / 2000: loss 1.578890
# iteration 1100 / 2000: loss 1.566770
# iteration 1200 / 2000: loss 1.561607
# iteration 1300 / 2000: loss 1.629699
# iteration 1400 / 2000: loss 1.561244
# iteration 1500 / 2000: loss 1.584586
# iteration 1600 / 2000: loss 1.604684
# iteration 1700 / 2000: loss 1.624053
# iteration 1800 / 2000: loss 1.511138
# iteration 1900 / 2000: loss 1.427182
# batch_size = 400, learning_rate = 0.001000, hidden_size = 50.000000, Valid_accuracy: 0.481000
# iteration 0 / 2000: loss 2.304134
# iteration 100 / 2000: loss 1.948144
# iteration 200 / 2000: loss 1.723173
# iteration 300 / 2000: loss 1.729157
# iteration 400 / 2000: loss 1.678871
# iteration 500 / 2000: loss 1.658767
# iteration 600 / 2000: loss 1.614301
# iteration 700 / 2000: loss 1.547188
# iteration 800 / 2000: loss 1.579467
# iteration 900 / 2000: loss 1.548421
# iteration 1000 / 2000: loss 1.535183
# iteration 1100 / 2000: loss 1.510164
# iteration 1200 / 2000: loss 1.466305
# iteration 1300 / 2000: loss 1.527087
# iteration 1400 / 2000: loss 1.565590
# iteration 1500 / 2000: loss 1.458217
# iteration 1600 / 2000: loss 1.491530
# iteration 1700 / 2000: loss 1.455747
# iteration 1800 / 2000: loss 1.475994
# iteration 1900 / 2000: loss 1.390971
# batch_size = 400, learning_rate = 0.001000, hidden_size = 100.000000, Valid_accuracy: 0.494000
# iteration 0 / 2000: loss 2.305721
# iteration 100 / 2000: loss 1.967984
# iteration 200 / 2000: loss 1.908614
# iteration 300 / 2000: loss 1.692220
# iteration 400 / 2000: loss 1.605301
# iteration 500 / 2000: loss 1.595449
# iteration 600 / 2000: loss 1.585616
# iteration 700 / 2000: loss 1.626193
# iteration 800 / 2000: loss 1.590181
# iteration 900 / 2000: loss 1.546436
# iteration 1000 / 2000: loss 1.552556
# iteration 1100 / 2000: loss 1.517385
# iteration 1200 / 2000: loss 1.585836
# iteration 1300 / 2000: loss 1.550235
# iteration 1400 / 2000: loss 1.509618
# iteration 1500 / 2000: loss 1.637043
# iteration 1600 / 2000: loss 1.550375
# iteration 1700 / 2000: loss 1.467045
# iteration 1800 / 2000: loss 1.474543
# iteration 1900 / 2000: loss 1.453780
# batch_size = 400, learning_rate = 0.001000, hidden_size = 200.000000, Valid_accuracy: 0.508000
# iteration 0 / 2000: loss 2.302951
# iteration 100 / 2000: loss 1.970482
# iteration 200 / 2000: loss 1.908714
# iteration 300 / 2000: loss 1.811917
# iteration 400 / 2000: loss 1.707152
# iteration 500 / 2000: loss 1.640561
# iteration 600 / 2000: loss 1.649906
# iteration 700 / 2000: loss 1.749537
# iteration 800 / 2000: loss 1.480939
# iteration 900 / 2000: loss 1.667449
# iteration 1000 / 2000: loss 1.574375
# iteration 1100 / 2000: loss 1.345160
# iteration 1200 / 2000: loss 1.608244
# iteration 1300 / 2000: loss 1.411619
# iteration 1400 / 2000: loss 1.358078
# iteration 1500 / 2000: loss 1.537584
# iteration 1600 / 2000: loss 1.408165
# iteration 1700 / 2000: loss 1.503795
# iteration 1800 / 2000: loss 1.517278
# iteration 1900 / 2000: loss 1.535445
# batch_size = 200, learning_rate = 0.001000, hidden_size = 50.000000, Valid_accuracy: 0.505000
# iteration 0 / 2000: loss 2.303338
# iteration 100 / 2000: loss 2.015252
# iteration 200 / 2000: loss 1.780842
# iteration 300 / 2000: loss 1.654622
# iteration 400 / 2000: loss 1.695549
# iteration 500 / 2000: loss 1.538864
# iteration 600 / 2000: loss 1.496537
# iteration 700 / 2000: loss 1.590058
# iteration 800 / 2000: loss 1.452106
# iteration 900 / 2000: loss 1.492497
# iteration 1000 / 2000: loss 1.536773
# iteration 1100 / 2000: loss 1.525345
# iteration 1200 / 2000: loss 1.443917
# iteration 1300 / 2000: loss 1.492834
# iteration 1400 / 2000: loss 1.491492
# iteration 1500 / 2000: loss 1.435368
# iteration 1600 / 2000: loss 1.433171
# iteration 1700 / 2000: loss 1.332368
# iteration 1800 / 2000: loss 1.522306
# iteration 1900 / 2000: loss 1.308286
# batch_size = 200, learning_rate = 0.001000, hidden_size = 100.000000, Valid_accuracy: 0.500000
# iteration 0 / 2000: loss 2.304115
# iteration 100 / 2000: loss 1.947162
# iteration 200 / 2000: loss 1.740357
# iteration 300 / 2000: loss 1.615644
# iteration 400 / 2000: loss 1.726799
# iteration 500 / 2000: loss 1.539388
# iteration 600 / 2000: loss 1.490402
# iteration 700 / 2000: loss 1.560180
# iteration 800 / 2000: loss 1.381558
# iteration 900 / 2000: loss 1.442477
# iteration 1000 / 2000: loss 1.384997
# iteration 1100 / 2000: loss 1.376307
# iteration 1200 / 2000: loss 1.502492
# iteration 1300 / 2000: loss 1.442270
# iteration 1400 / 2000: loss 1.366985
# iteration 1500 / 2000: loss 1.435828
# iteration 1600 / 2000: loss 1.391394
# iteration 1700 / 2000: loss 1.353533
# iteration 1800 / 2000: loss 1.346548
# iteration 1900 / 2000: loss 1.326528
# batch_size = 200, learning_rate = 0.001000, hidden_size = 200.000000, Valid_accuracy: 0.514000
# iteration 0 / 2000: loss 2.302966
# iteration 100 / 2000: loss 1.996545
# iteration 200 / 2000: loss 1.813851
# iteration 300 / 2000: loss 1.703090
# iteration 400 / 2000: loss 1.673933
# iteration 500 / 2000: loss 1.617941
# iteration 600 / 2000: loss 1.614745
# iteration 700 / 2000: loss 1.529335
# iteration 800 / 2000: loss 1.600970
# iteration 900 / 2000: loss 1.455451
# iteration 1000 / 2000: loss 1.551504
# iteration 1100 / 2000: loss 1.451248
# iteration 1200 / 2000: loss 1.476259
# iteration 1300 / 2000: loss 1.436684
# iteration 1400 / 2000: loss 1.423492
# iteration 1500 / 2000: loss 1.529462
# iteration 1600 / 2000: loss 1.501288
# iteration 1700 / 2000: loss 1.518622
# iteration 1800 / 2000: loss 1.402355
# iteration 1900 / 2000: loss 1.431332
# batch_size = 400, learning_rate = 0.001000, hidden_size = 50.000000, Valid_accuracy: 0.495000
# iteration 0 / 2000: loss 2.303373
# iteration 100 / 2000: loss 1.997943
# iteration 200 / 2000: loss 1.840264
# iteration 300 / 2000: loss 1.756281
# iteration 400 / 2000: loss 1.555990
# iteration 500 / 2000: loss 1.490417
# iteration 600 / 2000: loss 1.574690
# iteration 700 / 2000: loss 1.433663
# iteration 800 / 2000: loss 1.554590
# iteration 900 / 2000: loss 1.483527
# iteration 1000 / 2000: loss 1.398918
# iteration 1100 / 2000: loss 1.545579
# iteration 1200 / 2000: loss 1.483648
# iteration 1300 / 2000: loss 1.483922
# iteration 1400 / 2000: loss 1.421856
# iteration 1500 / 2000: loss 1.383900
# iteration 1600 / 2000: loss 1.438557
# iteration 1700 / 2000: loss 1.329362
# iteration 1800 / 2000: loss 1.415005
# iteration 1900 / 2000: loss 1.454654
# batch_size = 400, learning_rate = 0.001000, hidden_size = 100.000000, Valid_accuracy: 0.518000
# iteration 0 / 2000: loss 2.304110
# iteration 100 / 2000: loss 1.909170
# iteration 200 / 2000: loss 1.734859
# iteration 300 / 2000: loss 1.672562
# iteration 400 / 2000: loss 1.706983
# iteration 500 / 2000: loss 1.552861
# iteration 600 / 2000: loss 1.596859
# iteration 700 / 2000: loss 1.550743
# iteration 800 / 2000: loss 1.518085
# iteration 900 / 2000: loss 1.542190
# iteration 1000 / 2000: loss 1.494447
# iteration 1100 / 2000: loss 1.433931
# iteration 1200 / 2000: loss 1.472888
# iteration 1300 / 2000: loss 1.373672
# iteration 1400 / 2000: loss 1.368268
# iteration 1500 / 2000: loss 1.366166
# iteration 1600 / 2000: loss 1.407838
# iteration 1700 / 2000: loss 1.434027
# iteration 1800 / 2000: loss 1.380035
# iteration 1900 / 2000: loss 1.329922
# batch_size = 400, learning_rate = 0.001000, hidden_size = 200.000000, Valid_accuracy: 0.526000
# iteration 0 / 2000: loss 2.303340
# iteration 100 / 2000: loss 2.302991
# iteration 200 / 2000: loss 2.299748
# iteration 300 / 2000: loss 2.281616
# iteration 400 / 2000: loss 2.213401
# iteration 500 / 2000: loss 2.123556
# iteration 600 / 2000: loss 2.128646
# iteration 700 / 2000: loss 2.053381
# iteration 800 / 2000: loss 2.029763
# iteration 900 / 2000: loss 1.966590
# iteration 1000 / 2000: loss 1.993576
# iteration 1100 / 2000: loss 2.014979
# iteration 1200 / 2000: loss 1.961581
# iteration 1300 / 2000: loss 1.939843
# iteration 1400 / 2000: loss 1.966060
# iteration 1500 / 2000: loss 1.918402
# iteration 1600 / 2000: loss 1.874986
# iteration 1700 / 2000: loss 1.841137
# iteration 1800 / 2000: loss 1.840328
# iteration 1900 / 2000: loss 1.896089
# batch_size = 200, learning_rate = 0.000100, hidden_size = 50.000000, Valid_accuracy: 0.330000
# iteration 0 / 2000: loss 2.304113
# iteration 100 / 2000: loss 2.303169
# iteration 200 / 2000: loss 2.294148
# iteration 300 / 2000: loss 2.260495
# iteration 400 / 2000: loss 2.178592
# iteration 500 / 2000: loss 2.161116
# iteration 600 / 2000: loss 2.156333
# iteration 700 / 2000: loss 1.986703
# iteration 800 / 2000: loss 1.951216
# iteration 900 / 2000: loss 2.023708
# iteration 1000 / 2000: loss 1.951107
# iteration 1100 / 2000: loss 1.974833
# iteration 1200 / 2000: loss 1.924246
# iteration 1300 / 2000: loss 1.929505
# iteration 1400 / 2000: loss 1.852197
# iteration 1500 / 2000: loss 1.869214
# iteration 1600 / 2000: loss 1.886851
# iteration 1700 / 2000: loss 1.871464
# iteration 1800 / 2000: loss 1.852652
# iteration 1900 / 2000: loss 1.802674
# batch_size = 200, learning_rate = 0.000100, hidden_size = 100.000000, Valid_accuracy: 0.333000
# iteration 0 / 2000: loss 2.305608
# iteration 100 / 2000: loss 2.304244
# iteration 200 / 2000: loss 2.287272
# iteration 300 / 2000: loss 2.217707
# iteration 400 / 2000: loss 2.191740
# iteration 500 / 2000: loss 2.150887
# iteration 600 / 2000: loss 2.069299
# iteration 700 / 2000: loss 2.086993
# iteration 800 / 2000: loss 2.056787
# iteration 900 / 2000: loss 1.969527
# iteration 1000 / 2000: loss 2.025199
# iteration 1100 / 2000: loss 1.862301
# iteration 1200 / 2000: loss 1.829889
# iteration 1300 / 2000: loss 1.951642
# iteration 1400 / 2000: loss 1.961415
# iteration 1500 / 2000: loss 1.919377
# iteration 1600 / 2000: loss 1.853482
# iteration 1700 / 2000: loss 1.920062
# iteration 1800 / 2000: loss 1.863066
# iteration 1900 / 2000: loss 1.921367
# batch_size = 200, learning_rate = 0.000100, hidden_size = 200.000000, Valid_accuracy: 0.341000
# iteration 0 / 2000: loss 2.303359
# iteration 100 / 2000: loss 2.302935
# iteration 200 / 2000: loss 2.300268
# iteration 300 / 2000: loss 2.280476
# iteration 400 / 2000: loss 2.205574
# iteration 500 / 2000: loss 2.173368
# iteration 600 / 2000: loss 2.090211
# iteration 700 / 2000: loss 2.072821
# iteration 800 / 2000: loss 2.041213
# iteration 900 / 2000: loss 2.034800
# iteration 1000 / 2000: loss 2.052427
# iteration 1100 / 2000: loss 1.916355
# iteration 1200 / 2000: loss 1.958202
# iteration 1300 / 2000: loss 1.876977
# iteration 1400 / 2000: loss 2.018032
# iteration 1500 / 2000: loss 1.906834
# iteration 1600 / 2000: loss 1.950898
# iteration 1700 / 2000: loss 1.874592
# iteration 1800 / 2000: loss 1.903571
# iteration 1900 / 2000: loss 1.866019
# batch_size = 400, learning_rate = 0.000100, hidden_size = 50.000000, Valid_accuracy: 0.327000
# iteration 0 / 2000: loss 2.304110
# iteration 100 / 2000: loss 2.303351
# iteration 200 / 2000: loss 2.295616
# iteration 300 / 2000: loss 2.266166
# iteration 400 / 2000: loss 2.185091
# iteration 500 / 2000: loss 2.132815
# iteration 600 / 2000: loss 2.094875
# iteration 700 / 2000: loss 1.973408
# iteration 800 / 2000: loss 2.034205
# iteration 900 / 2000: loss 1.984669
# iteration 1000 / 2000: loss 1.993989
# iteration 1100 / 2000: loss 1.961631
# iteration 1200 / 2000: loss 1.902446
# iteration 1300 / 2000: loss 1.971957
# iteration 1400 / 2000: loss 1.914147
# iteration 1500 / 2000: loss 1.951816
# iteration 1600 / 2000: loss 1.871127
# iteration 1700 / 2000: loss 1.849495
# iteration 1800 / 2000: loss 1.818400
# iteration 1900 / 2000: loss 1.875228
# batch_size = 400, learning_rate = 0.000100, hidden_size = 100.000000, Valid_accuracy: 0.342000
# iteration 0 / 2000: loss 2.305668
# iteration 100 / 2000: loss 2.303818
# iteration 200 / 2000: loss 2.291205
# iteration 300 / 2000: loss 2.232232
# iteration 400 / 2000: loss 2.157991
# iteration 500 / 2000: loss 2.072956
# iteration 600 / 2000: loss 2.098983
# iteration 700 / 2000: loss 2.001859
# iteration 800 / 2000: loss 2.017866
# iteration 900 / 2000: loss 1.975762
# iteration 1000 / 2000: loss 1.987838
# iteration 1100 / 2000: loss 1.953444
# iteration 1200 / 2000: loss 1.979474
# iteration 1300 / 2000: loss 1.919116
# iteration 1400 / 2000: loss 1.923389
# iteration 1500 / 2000: loss 1.972669
# iteration 1600 / 2000: loss 1.904228
# iteration 1700 / 2000: loss 1.903734
# iteration 1800 / 2000: loss 1.824623
# iteration 1900 / 2000: loss 1.909728
# batch_size = 400, learning_rate = 0.000100, hidden_size = 200.000000, Valid_accuracy: 0.345000
# iteration 0 / 2000: loss 2.302953
# iteration 100 / 2000: loss 2.302552
# iteration 200 / 2000: loss 2.297711
# iteration 300 / 2000: loss 2.262349
# iteration 400 / 2000: loss 2.184250
# iteration 500 / 2000: loss 2.173388
# iteration 600 / 2000: loss 2.135656
# iteration 700 / 2000: loss 2.081478
# iteration 800 / 2000: loss 2.039617
# iteration 900 / 2000: loss 2.006093
# iteration 1000 / 2000: loss 1.950359
# iteration 1100 / 2000: loss 1.979566
# iteration 1200 / 2000: loss 1.943779
# iteration 1300 / 2000: loss 1.920994
# iteration 1400 / 2000: loss 1.987712
# iteration 1500 / 2000: loss 1.893666
# iteration 1600 / 2000: loss 1.856849
# iteration 1700 / 2000: loss 1.897998
# iteration 1800 / 2000: loss 1.808883
# iteration 1900 / 2000: loss 1.727175
# batch_size = 200, learning_rate = 0.000100, hidden_size = 50.000000, Valid_accuracy: 0.319000
# iteration 0 / 2000: loss 2.303330
# iteration 100 / 2000: loss 2.302593
# iteration 200 / 2000: loss 2.292348
# iteration 300 / 2000: loss 2.238750
# iteration 400 / 2000: loss 2.199616
# iteration 500 / 2000: loss 2.062777
# iteration 600 / 2000: loss 2.069644
# iteration 700 / 2000: loss 2.005500
# iteration 800 / 2000: loss 1.989672
# iteration 900 / 2000: loss 1.999837
# iteration 1000 / 2000: loss 1.991371
# iteration 1100 / 2000: loss 1.932949
# iteration 1200 / 2000: loss 1.846513
# iteration 1300 / 2000: loss 1.946646
# iteration 1400 / 2000: loss 1.866302
# iteration 1500 / 2000: loss 1.989027
# iteration 1600 / 2000: loss 1.964875
# iteration 1700 / 2000: loss 1.808488
# iteration 1800 / 2000: loss 1.907332
# iteration 1900 / 2000: loss 1.818100
# batch_size = 200, learning_rate = 0.000100, hidden_size = 100.000000, Valid_accuracy: 0.340000
# iteration 0 / 2000: loss 2.304094
# iteration 100 / 2000: loss 2.302556
# iteration 200 / 2000: loss 2.288822
# iteration 300 / 2000: loss 2.250727
# iteration 400 / 2000: loss 2.162765
# iteration 500 / 2000: loss 2.060196
# iteration 600 / 2000: loss 2.091130
# iteration 700 / 2000: loss 2.061032
# iteration 800 / 2000: loss 1.996778
# iteration 900 / 2000: loss 1.996635
# iteration 1000 / 2000: loss 1.996685
# iteration 1100 / 2000: loss 1.936597
# iteration 1200 / 2000: loss 1.931963
# iteration 1300 / 2000: loss 1.948110
# iteration 1400 / 2000: loss 1.792059
# iteration 1500 / 2000: loss 1.874252
# iteration 1600 / 2000: loss 1.968239
# iteration 1700 / 2000: loss 1.842588
# iteration 1800 / 2000: loss 1.808828
# iteration 1900 / 2000: loss 1.819520
# batch_size = 200, learning_rate = 0.000100, hidden_size = 200.000000, Valid_accuracy: 0.357000
# iteration 0 / 2000: loss 2.302968
# iteration 100 / 2000: loss 2.302617
# iteration 200 / 2000: loss 2.299204
# iteration 300 / 2000: loss 2.270349
# iteration 400 / 2000: loss 2.222104
# iteration 500 / 2000: loss 2.146726
# iteration 600 / 2000: loss 2.109124
# iteration 700 / 2000: loss 2.055346
# iteration 800 / 2000: loss 2.036231
# iteration 900 / 2000: loss 1.959077
# iteration 1000 / 2000: loss 2.012767
# iteration 1100 / 2000: loss 1.947788
# iteration 1200 / 2000: loss 2.001563
# iteration 1300 / 2000: loss 1.935675
# iteration 1400 / 2000: loss 1.897308
# iteration 1500 / 2000: loss 1.871274
# iteration 1600 / 2000: loss 1.873204
# iteration 1700 / 2000: loss 1.867234
# iteration 1800 / 2000: loss 1.846434
# iteration 1900 / 2000: loss 1.849075
# batch_size = 400, learning_rate = 0.000100, hidden_size = 50.000000, Valid_accuracy: 0.335000
# iteration 0 / 2000: loss 2.303375
# iteration 100 / 2000: loss 2.302653
# iteration 200 / 2000: loss 2.298652
# iteration 300 / 2000: loss 2.266681
# iteration 400 / 2000: loss 2.210148
# iteration 500 / 2000: loss 2.164068
# iteration 600 / 2000: loss 2.121656
# iteration 700 / 2000: loss 2.031123
# iteration 800 / 2000: loss 2.058456
# iteration 900 / 2000: loss 1.946537
# iteration 1000 / 2000: loss 1.940057
# iteration 1100 / 2000: loss 1.914051
# iteration 1200 / 2000: loss 1.939876
# iteration 1300 / 2000: loss 1.853122
# iteration 1400 / 2000: loss 1.909459
# iteration 1500 / 2000: loss 1.887187
# iteration 1600 / 2000: loss 1.908581
# iteration 1700 / 2000: loss 1.895321
# iteration 1800 / 2000: loss 1.880320
# iteration 1900 / 2000: loss 1.912860
# batch_size = 400, learning_rate = 0.000100, hidden_size = 100.000000, Valid_accuracy: 0.334000
# iteration 0 / 2000: loss 2.304161
# iteration 100 / 2000: loss 2.302638
# iteration 200 / 2000: loss 2.289303
# iteration 300 / 2000: loss 2.242210
# iteration 400 / 2000: loss 2.173342
# iteration 500 / 2000: loss 2.107290
# iteration 600 / 2000: loss 2.067945
# iteration 700 / 2000: loss 2.057886
# iteration 800 / 2000: loss 2.009634
# iteration 900 / 2000: loss 1.964035
# iteration 1000 / 2000: loss 1.974348
# iteration 1100 / 2000: loss 1.935592
# iteration 1200 / 2000: loss 1.932123
# iteration 1300 / 2000: loss 1.913697
# iteration 1400 / 2000: loss 1.907909
# iteration 1500 / 2000: loss 1.790961
# iteration 1600 / 2000: loss 1.867947
# iteration 1700 / 2000: loss 1.866311
# iteration 1800 / 2000: loss 1.860140
# iteration 1900 / 2000: loss 1.825554
# batch_size = 400, learning_rate = 0.000100, hidden_size = 200.000000, Valid_accuracy: 0.347000
# iteration 0 / 2000: loss 2.303347
# iteration 100 / 2000: loss 2.303323
# iteration 200 / 2000: loss 2.303309
# iteration 300 / 2000: loss 2.303283
# iteration 400 / 2000: loss 2.303264
# iteration 500 / 2000: loss 2.303265
# iteration 600 / 2000: loss 2.303214
# iteration 700 / 2000: loss 2.303224
# iteration 800 / 2000: loss 2.303118
# iteration 900 / 2000: loss 2.303105
# iteration 1000 / 2000: loss 2.302986
# iteration 1100 / 2000: loss 2.303085
# iteration 1200 / 2000: loss 2.302943
# iteration 1300 / 2000: loss 2.303011
# iteration 1400 / 2000: loss 2.302783
# iteration 1500 / 2000: loss 2.302659
# iteration 1600 / 2000: loss 2.302591
# iteration 1700 / 2000: loss 2.302585
# iteration 1800 / 2000: loss 2.302517
# iteration 1900 / 2000: loss 2.302780
# batch_size = 200, learning_rate = 0.000010, hidden_size = 50.000000, Valid_accuracy: 0.202000
# iteration 0 / 2000: loss 2.304154
# iteration 100 / 2000: loss 2.304111
# iteration 200 / 2000: loss 2.304053
# iteration 300 / 2000: loss 2.303998
# iteration 400 / 2000: loss 2.303988
# iteration 500 / 2000: loss 2.303951
# iteration 600 / 2000: loss 2.303847
# iteration 700 / 2000: loss 2.303819
# iteration 800 / 2000: loss 2.303663
# iteration 900 / 2000: loss 2.303710
# iteration 1000 / 2000: loss 2.303569
# iteration 1100 / 2000: loss 2.303488
# iteration 1200 / 2000: loss 2.303580
# iteration 1300 / 2000: loss 2.303416
# iteration 1400 / 2000: loss 2.303176
# iteration 1500 / 2000: loss 2.303017
# iteration 1600 / 2000: loss 2.303073
# iteration 1700 / 2000: loss 2.303114
# iteration 1800 / 2000: loss 2.302927
# iteration 1900 / 2000: loss 2.302577
# batch_size = 200, learning_rate = 0.000010, hidden_size = 100.000000, Valid_accuracy: 0.247000
# iteration 0 / 2000: loss 2.305610
# iteration 100 / 2000: loss 2.305545
# iteration 200 / 2000: loss 2.305408
# iteration 300 / 2000: loss 2.305386
# iteration 400 / 2000: loss 2.305262
# iteration 500 / 2000: loss 2.305069
# iteration 600 / 2000: loss 2.305002
# iteration 700 / 2000: loss 2.304815
# iteration 800 / 2000: loss 2.304721
# iteration 900 / 2000: loss 2.304610
# iteration 1000 / 2000: loss 2.304315
# iteration 1100 / 2000: loss 2.304056
# iteration 1200 / 2000: loss 2.303869
# iteration 1300 / 2000: loss 2.303778
# iteration 1400 / 2000: loss 2.303996
# iteration 1500 / 2000: loss 2.303162
# iteration 1600 / 2000: loss 2.302771
# iteration 1700 / 2000: loss 2.301993
# iteration 1800 / 2000: loss 2.302313
# iteration 1900 / 2000: loss 2.300808
# batch_size = 200, learning_rate = 0.000010, hidden_size = 200.000000, Valid_accuracy: 0.211000
# iteration 0 / 2000: loss 2.303366
# iteration 100 / 2000: loss 2.303328
# iteration 200 / 2000: loss 2.303312
# iteration 300 / 2000: loss 2.303296
# iteration 400 / 2000: loss 2.303283
# iteration 500 / 2000: loss 2.303254
# iteration 600 / 2000: loss 2.303259
# iteration 700 / 2000: loss 2.303189
# iteration 800 / 2000: loss 2.303174
# iteration 900 / 2000: loss 2.303147
# iteration 1000 / 2000: loss 2.303058
# iteration 1100 / 2000: loss 2.303072
# iteration 1200 / 2000: loss 2.303003
# iteration 1300 / 2000: loss 2.302968
# iteration 1400 / 2000: loss 2.302982
# iteration 1500 / 2000: loss 2.302896
# iteration 1600 / 2000: loss 2.302879
# iteration 1700 / 2000: loss 2.302785
# iteration 1800 / 2000: loss 2.302686
# iteration 1900 / 2000: loss 2.302667
# batch_size = 400, learning_rate = 0.000010, hidden_size = 50.000000, Valid_accuracy: 0.204000
# iteration 0 / 2000: loss 2.304152
# iteration 100 / 2000: loss 2.304104
# iteration 200 / 2000: loss 2.304072
# iteration 300 / 2000: loss 2.304015
# iteration 400 / 2000: loss 2.303973
# iteration 500 / 2000: loss 2.303915
# iteration 600 / 2000: loss 2.303837
# iteration 700 / 2000: loss 2.303835
# iteration 800 / 2000: loss 2.303731
# iteration 900 / 2000: loss 2.303677
# iteration 1000 / 2000: loss 2.303584
# iteration 1100 / 2000: loss 2.303459
# iteration 1200 / 2000: loss 2.303476
# iteration 1300 / 2000: loss 2.303406
# iteration 1400 / 2000: loss 2.303097
# iteration 1500 / 2000: loss 2.303152
# iteration 1600 / 2000: loss 2.303033
# iteration 1700 / 2000: loss 2.302727
# iteration 1800 / 2000: loss 2.302549
# iteration 1900 / 2000: loss 2.302490
# batch_size = 400, learning_rate = 0.000010, hidden_size = 100.000000, Valid_accuracy: 0.234000
# iteration 0 / 2000: loss 2.305659
# iteration 100 / 2000: loss 2.305594
# iteration 200 / 2000: loss 2.305511
# iteration 300 / 2000: loss 2.305423
# iteration 400 / 2000: loss 2.305324
# iteration 500 / 2000: loss 2.305253
# iteration 600 / 2000: loss 2.305140
# iteration 700 / 2000: loss 2.304971
# iteration 800 / 2000: loss 2.304714
# iteration 900 / 2000: loss 2.304731
# iteration 1000 / 2000: loss 2.304445
# iteration 1100 / 2000: loss 2.304280
# iteration 1200 / 2000: loss 2.303977
# iteration 1300 / 2000: loss 2.303961
# iteration 1400 / 2000: loss 2.303929
# iteration 1500 / 2000: loss 2.303550
# iteration 1600 / 2000: loss 2.302907
# iteration 1700 / 2000: loss 2.302618
# iteration 1800 / 2000: loss 2.302841
# iteration 1900 / 2000: loss 2.302438
# batch_size = 400, learning_rate = 0.000010, hidden_size = 200.000000, Valid_accuracy: 0.204000
# iteration 0 / 2000: loss 2.303002
# iteration 100 / 2000: loss 2.302981
# iteration 200 / 2000: loss 2.302955
# iteration 300 / 2000: loss 2.302921
# iteration 400 / 2000: loss 2.302911
# iteration 500 / 2000: loss 2.302878
# iteration 600 / 2000: loss 2.302879
# iteration 700 / 2000: loss 2.302837
# iteration 800 / 2000: loss 2.302788
# iteration 900 / 2000: loss 2.302772
# iteration 1000 / 2000: loss 2.302739
# iteration 1100 / 2000: loss 2.302665
# iteration 1200 / 2000: loss 2.302638
# iteration 1300 / 2000: loss 2.302587
# iteration 1400 / 2000: loss 2.302623
# iteration 1500 / 2000: loss 2.302559
# iteration 1600 / 2000: loss 2.302622
# iteration 1700 / 2000: loss 2.302239
# iteration 1800 / 2000: loss 2.302327
# iteration 1900 / 2000: loss 2.302372
# batch_size = 200, learning_rate = 0.000010, hidden_size = 50.000000, Valid_accuracy: 0.219000
# iteration 0 / 2000: loss 2.303396
# iteration 100 / 2000: loss 2.303352
# iteration 200 / 2000: loss 2.303314
# iteration 300 / 2000: loss 2.303284
# iteration 400 / 2000: loss 2.303220
# iteration 500 / 2000: loss 2.303241
# iteration 600 / 2000: loss 2.303141
# iteration 700 / 2000: loss 2.303104
# iteration 800 / 2000: loss 2.303041
# iteration 900 / 2000: loss 2.303021
# iteration 1000 / 2000: loss 2.302952
# iteration 1100 / 2000: loss 2.302878
# iteration 1200 / 2000: loss 2.302637
# iteration 1300 / 2000: loss 2.302656
# iteration 1400 / 2000: loss 2.302461
# iteration 1500 / 2000: loss 2.302310
# iteration 1600 / 2000: loss 2.302256
# iteration 1700 / 2000: loss 2.302229
# iteration 1800 / 2000: loss 2.301982
# iteration 1900 / 2000: loss 2.301558
# batch_size = 200, learning_rate = 0.000010, hidden_size = 100.000000, Valid_accuracy: 0.232000
# iteration 0 / 2000: loss 2.304145
# iteration 100 / 2000: loss 2.304015
# iteration 200 / 2000: loss 2.303951
# iteration 300 / 2000: loss 2.303879
# iteration 400 / 2000: loss 2.303791
# iteration 500 / 2000: loss 2.303649
# iteration 600 / 2000: loss 2.303421
# iteration 700 / 2000: loss 2.303585
# iteration 800 / 2000: loss 2.303326
# iteration 900 / 2000: loss 2.303157
# iteration 1000 / 2000: loss 2.303013
# iteration 1100 / 2000: loss 2.302483
# iteration 1200 / 2000: loss 2.302336
# iteration 1300 / 2000: loss 2.302406
# iteration 1400 / 2000: loss 2.301740
# iteration 1500 / 2000: loss 2.302239
# iteration 1600 / 2000: loss 2.300886
# iteration 1700 / 2000: loss 2.301409
# iteration 1800 / 2000: loss 2.300682
# iteration 1900 / 2000: loss 2.300704
# batch_size = 200, learning_rate = 0.000010, hidden_size = 200.000000, Valid_accuracy: 0.204000
# iteration 0 / 2000: loss 2.302966
# iteration 100 / 2000: loss 2.302960
# iteration 200 / 2000: loss 2.302929
# iteration 300 / 2000: loss 2.302922
# iteration 400 / 2000: loss 2.302904
# iteration 500 / 2000: loss 2.302862
# iteration 600 / 2000: loss 2.302846
# iteration 700 / 2000: loss 2.302802
# iteration 800 / 2000: loss 2.302811
# iteration 900 / 2000: loss 2.302720
# iteration 1000 / 2000: loss 2.302721
# iteration 1100 / 2000: loss 2.302652
# iteration 1200 / 2000: loss 2.302578
# iteration 1300 / 2000: loss 2.302533
# iteration 1400 / 2000: loss 2.302432
# iteration 1500 / 2000: loss 2.302497
# iteration 1600 / 2000: loss 2.302330
# iteration 1700 / 2000: loss 2.302341
# iteration 1800 / 2000: loss 2.302332
# iteration 1900 / 2000: loss 2.302176
# batch_size = 400, learning_rate = 0.000010, hidden_size = 50.000000, Valid_accuracy: 0.213000
# iteration 0 / 2000: loss 2.303350
# iteration 100 / 2000: loss 2.303311
# iteration 200 / 2000: loss 2.303277
# iteration 300 / 2000: loss 2.303229
# iteration 400 / 2000: loss 2.303177
# iteration 500 / 2000: loss 2.303089
# iteration 600 / 2000: loss 2.303092
# iteration 700 / 2000: loss 2.302977
# iteration 800 / 2000: loss 2.302943
# iteration 900 / 2000: loss 2.302864
# iteration 1000 / 2000: loss 2.302822
# iteration 1100 / 2000: loss 2.302503
# iteration 1200 / 2000: loss 2.302430
# iteration 1300 / 2000: loss 2.302422
# iteration 1400 / 2000: loss 2.302208
# iteration 1500 / 2000: loss 2.302383
# iteration 1600 / 2000: loss 2.302263
# iteration 1700 / 2000: loss 2.301876
# iteration 1800 / 2000: loss 2.301111
# iteration 1900 / 2000: loss 2.301778
# batch_size = 400, learning_rate = 0.000010, hidden_size = 100.000000, Valid_accuracy: 0.213000
# iteration 0 / 2000: loss 2.304142
# iteration 100 / 2000: loss 2.304053
# iteration 200 / 2000: loss 2.303989
# iteration 300 / 2000: loss 2.303863
# iteration 400 / 2000: loss 2.303834
# iteration 500 / 2000: loss 2.303685
# iteration 600 / 2000: loss 2.303497
# iteration 700 / 2000: loss 2.303451
# iteration 800 / 2000: loss 2.303355
# iteration 900 / 2000: loss 2.303060
# iteration 1000 / 2000: loss 2.303075
# iteration 1100 / 2000: loss 2.302703
# iteration 1200 / 2000: loss 2.302576
# iteration 1300 / 2000: loss 2.302217
# iteration 1400 / 2000: loss 2.301619
# iteration 1500 / 2000: loss 2.301581
# iteration 1600 / 2000: loss 2.300900
# iteration 1700 / 2000: loss 2.301573
# iteration 1800 / 2000: loss 2.300775
# iteration 1900 / 2000: loss 2.300172
# batch_size = 400, learning_rate = 0.000010, hidden_size = 200.000000, Valid_accuracy: 0.228000

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print('Test accuracy: ', test_acc)
# Out:
# Test accuracy:  0.528
